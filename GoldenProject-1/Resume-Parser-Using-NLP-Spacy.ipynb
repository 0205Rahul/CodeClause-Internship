# %%
import spacy
import re
import fitz  # PyMuPDF for PDF text extraction
from docx import Document  # python-docx for DOCX handling
import requests
import json, pdfplumber
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from tempfile import NamedTemporaryFile

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
#Upload File link
resume_drive_link = "https://drive.google.com/file/d/11n3y9ApkUybZpjkM4Qs8r8xR2rRIejJS/view?usp=sharing"

# %%
resume_drive_link
# Out:
# 'https://drive.google.com/file/d/11n3y9ApkUybZpjkM4Qs8r8xR2rRIejJS/view?usp=sharing'

# %%
file_id = resume_drive_link.split("/")[-2]
file_id
# Out:
# '11n3y9ApkUybZpjkM4Qs8r8xR2rRIejJS'

# %%
download_resume = f"https://drive.google.com/uc?export=download&id={file_id}"
download_resume
# Out:
# 'https://drive.google.com/uc?export=download&id=11n3y9ApkUybZpjkM4Qs8r8xR2rRIejJS'

# %%
req_response = requests.get(download_resume)
if req_response.status_code != 200:
    print("Error downloading the file.")
else:
    resume_content = req_response.content

# %%
print(resume_content)
# Out:
# b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n<</Type/Catalog/Pages 2 0 R/Lang(en) /StructTreeRoot 46 0 R/MarkInfo<</Marked true>>/Metadata 281 0 R/ViewerPreferences 282 0 R>>\r\nendobj\r\n2 0 obj\r\n<</Type/Pages/Count 1/Kids[ 3 0 R] >>\r\nendobj\r\n3 0 obj\r\n<</Type/Page/Parent 2 0 R/Resources<</Font<</F1 5 0 R/F2 9 0 R/F3 11 0 R/F4 20 0 R/F5 25 0 R/F6 27 0 R/F7 32 0 R/F8 34 0 R>>/ExtGState<</GS7 7 0 R/GS8 8 0 R>>/XObject<</Image40 40 0 R/Image44 44 0 R>>/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] >>/Annots[ 16 0 R 17 0 R 18 0 R 19 0 R 39 0 R 41 0 R 42 0 R 43 0 R] /MediaBox[ 0 0 612 792] /Contents 4 0 R/Group<</Type/Group/S/Transparency/CS/DeviceRGB>>/Tabs/S/StructParents 0>>\r\nendobj\r\n4 0 obj\r\n<</Filter/FlateDecode/Length 10281>>\r\nstream\r\nx\x9c\xcd][s\xdb\xc6\x92~w\x95\xff\x03^\xb6\x8a<k\xc1\x98+\x80\xd4)\xd7\xca\x92\xed8\xb1\x15\xdbr\xe2\xad:\xd9\x07\x9a\x82%\xc4\x14\xa5\x90\x94}\x9c_\xbf\xd3=\x83\x0b93$\x0c\x0c\x94\x93\xaa\xc8$\x08\xe0\x9bkw\xcf7\xdd=\xd1\xe3\xf3\xdb\xd92\xfa\xe7?\x1f\xbf>yy\x1a%\x8f_\xcd\x96\x97\xd1\xa4X\x1e\xfdz>}\xf2$zzz\x12\xfd\xf9\xf0A\x12\'\xf0_Nh\x94DR\xfdMs\x1a\xad\x8a\x87\x0f>\xfc#Z>|\xf0\xf4\xfd\xc3\x07\x8f\x9f\x93\x88\xf08\xe1\xd1\xfbO\x0f\x1f\x10u_\x12\x91\x88\nu)\x8f\xd2T\xc4\x8cF\xef\xaf\xd5}/\xce\xd3\xe8r\xad\xde\x19]\xe2\xb7\xcc|{\xf1\xf0\xc1\xbf&\xef\xa6Gl2\x9b\xf2\xc9\xd5\xddbzD\'\xd1\xd3\xab)!\x93\x1b\xb8\xfcU]\xbeV\xff\x97\xf0e\xfey\xfa\x7f\xd1\xfb\x9f\x1e>x\xa6\xb0\xdf>|0\xa4\x90Ldq\xc2\xda\x85\xc4\xb2\x99"E\xdb@\xd1\xb3\xd7\'Q\xb4\xddldH\xb3\xd1H\xfd\xb0\xd5f4\x8b9\x89RIb"\xad\xe2\x1c\xafo\xcbU\xb9\xbc\xecW}\x1b,M\xf6\x80E\xc1P\xd8\x1e\x94\xd3\xd9TN6\xb3PX\xb9\x88\xf3t\xf4\x1a\xe5\xd9\x1e\x94\xe3%Ti1\xcd&\xdf\xd6\xd3|\xb2\x89\xd4\xa7\xc7\x81\x90\x19\xa71\xf3\xb6\xe5\xb9\xc2\x9d\xc3$)\x96\x9br\rSh\x13\n7c\xb1\xc8;\xb6\xabk\x96\xd0\x81\xb3$\x89\x85\xdc*\x11Q=\x9d\xaa>\xe0\x99k\xde\xfe<=\xe2\x93\x9b\xc5TL>\xcf6\xaaUf\x8f\xa2)\xa1\x93\x0f\xc5Z5\xcfF]\x8e\x9eB\xf3\x14pqy9[\xa8[\x1eE/\xa7l\xb2\xbc(\xd5\xaf\xfd\x87\xa3UNFD\x9c\x08_9{\x8eH\xe6\x04Jc\xe1k\x90\x7f&2cO\xc2U\x8a\xaaa\x98\x07\xae\x14q\x02\xf18\'>\xa07Wjj\xc5\x01\xfb\x8a\xe5q\x1a\xbaZN 5\x8d9\xf3\x01\xfd\xf74\x9d\xe4$ \x9aRq\x99w\xaa\x84\xac\x96\x12\x0f\xfea\x91\xab\xeb\xa0\xcf\x99Rr)| 2\x1c4\'2\xe6]\xeb\xe8\x12Pl\x98\xf5\x93\xc7\xb9\xdcQ\xe4,&\xaa\x8b\x99\x8cef\n\x04\xd7W\x97\xd5\xa7wX\xb4gh\xd8\x1c\xe5J\xe6\x1c\x89I\xb9\xf8\xa1o\x9b\xd8%\x10\x14%\xcf\xa1\x12\xf4\x1e\x00\x0eD\x8e"\xa8\x8d\xd8t\xc2\n\xcd\xbb\xab\xe9Q:\xb9\x83\xba.\xa6\x84M>\xc2\xa7+\xf8s\x03\x7f\xbe^c+(\x03OL(|L\xf4\x1f\xa9\xbe\xc9\xc9\xff\xa8\xab\x97p\xe1\x1a\xc4\xfb\xac\\\xc4 \xc4\xe77\xf0\xca\xeb`\xb5`\x99\xd2\xee\xf9w\xb7\x9bkP\xf1\xd0\x83*\xa18\xa8@*\xd2=E{\x05F\xc0\xf23\xb4Kq\xf1rz\x94M\x96\x01\xc7\x15\x171\x17\xdb\x85\x08 N\x1c8)ZYn\x9cw\xaa\x8a\xed\xc1\x04\x8b\x055\xbevF\xd1\xc1\x1e\x12\xc3\xec\x12{\xf0\x90,\xa6y\xe0\xc6a\x0e\x1c\x9a\xc4\x19s\xe3DG\xea\xad\\]\x9dk\xbd\xaf\xde\xbf\xa3\xfb]-!\x03\x8fUFS\xd4q\x87\xc6\xea\x0b\x98\xcb\xe5\x06f\xf2\x8f\xf0\xf1\xee\xa3\xea\xd9p\xa3\x95Ie\xb9\xde\xc3heR\xc6\x89w\xb4\xa2\x18k\x04\x9a\x80?\xbb#\xf8\xf0`M\x03\x0fV\x9e\xe4(\xe9:\xb5\x8d\xab@Y\xe81#\xa34\x111\xb1-=\x18\x1e\xef~\x81vz\x0e\x1f\xc1T\x07!\xf7\xac\xaf\xa9iAgj)L\xb9\x07\xbeCS\xe4\xa1\x05I\x06L\x85\xccI\x9c\xda\xaa\xf4%\x88\xbaHY\r\x99\xd6\x9d\xb3/(\xea\xa7$1Wg\xea\x1f\x92$\x93\xcf\xf0kQ(3y\t\x9f\xf4\x8f\xe5\x12\xe6\xd9\xa6X\xc1?\xc5z\x03W%\\M\xcd\r_\x95\x14\x95J_g\xfay}\xff\xe5\xd6\x0b\xaa[7W\xf8\x12\xf5%\xcb&\x9f\xa0Xe\xb1\xb8hn\xbdQj\xfbSS\xda\xd3\x99Z\xea\xd7\xdf\xce\xe7e\x01\x86 \x96m^\xc0\x0f\x8f\xe1\x0e,<Q\x0bi(\xc6l\xf1-\xdc$\xe5\x04\x96\xb1\x9eV\xdd\x94\xf3u8(!\xc0\x16\xf6@\xa1\xe1\xa2\x1b\xa1\xd5\x97\xb3\xebi\xd5n\xc5\x12zt\x03&\x12\xf60\x8a\x88\xb5\x1a\xf5\xe5l\xbd\x81\x7f\xe6p\x9f\xb2\x1a\xf1\xbeV\x83\xe3\xc7\xe2\x02\xae\x96\xf3\xd9\x06\xba\xbe\xf5\xeb\xe6\x06\xba\x0bzK\x9a;a\xcc|\xc1O\x0b\xec\xf5\xdbv\x8fK\xf3\x18\x00oVPf\xd4\xaf\xd8_\xfa\xd7\xefl\xae\xa1\x96\x19\xce\t5U\xa9MB\xe8\x96\x80\xd1\xa2j\xa1\xbar\xb6\x88\xa0e\xa1\xe8z\x14/\x16kX\ ...

# %%
# Save the PDF content to a temporary file
with NamedTemporaryFile(suffix=".pdf", delete=False) as temp_file:
    temp_file.write(resume_content)
    temp_pdf_path = temp_file.name

# Open the PDF using pdfplumber
with pdfplumber.open(temp_pdf_path) as pdf:
    resume_text = ""
    for page in pdf.pages:
        resume_text += page.extract_text()

# %%
resume_gen = nlp(resume_text)
resume_gen
# Out:
# Rahul Bhowmick
# Aspiring Data Analyst /Scientist
# Kolkata, West Bengal, India ⋄ Ph. +91 97483 22716
# Email: rahulbhowmick2002@gmail.com
# LinkedIn: Rahul Bhowmick ⋄ GitHub: 0205Rahul
# PROFILE
# I have a keen interest in working in the field of Data Science/Data Analytics. I am enthusiastic and dedicated to developing strong
# analytical skills, having worked on real-time projects. I have the ability to work well in a team and am always ready to upskill myself.
# EDUCATION
# • B. Tech (Computer Science and Engineering), KIIT University, Bhubaneswar – CGPA: 9.74 2020-Present
# • Senior Secondary (12th CBSE), South Point High School, Kolkata – Percentage: 88.80% 2020
# • Secondary (10th CBSE), South Point High School, Kolkata – Percentage: 84.80% 2018
# TRAINING EXPERIENCE
# • Training, Metvy, Data Analytics Training, Remote. 2023
# o Gained insights, and skills: Acquired knowledge of working with data using MS Excel, Power BI, Python, and SQL.
# o Accomplishments: Built multiple real-data projects, and awarded signed L.O.R. from Metvy.
# PROJECT / RESEARCH
# • Academic Project: E-Commerce Product Recommendation Systems 2023
# o Tools/ Tech: MS Excel, Python, ML, Jupyter NB, SQL, Flask, HTML.
# o Overview: We have used data scrapping to obtain data. Batch-processing and ML models have been implemented to build the
# required recommendation system.
# • Research: Telemedical Analysis - Brain-Stroke Prediction 2022 – Present
# o Tools/ Tech: MS Excel, Python, ML, Jupyter NB, Power BI, Overleaf.
# o Overview: We have analyzed datasets, and build ML models using algorithms like KNN, SVM, ANN to predict whether a person
# is suffering from brain-stroke or not.
# • Project: Spotting Areal Differences between Two Similar Images 2023
# o Tools/ Tech: Python, Jupyter NB, OpenCV, Tkinter.
# o Overview: Real-time captured images, as well as downloaded images have been monitored. Image differences have been found
# out using NumPy array calculations, setting threshold limits, and applying contours, present in CV2 library.
# • Training Project: Analysis on Shipping Orders Dataset 2023
# o Tools/ Tech: MS Excel, Data Analysis, Data Visualizations, Pivot Tables.
# o Overview: Deep Analysis of shipping orders dataset has been performed by implementing data cleaning, formatting data, and
# visualization techniques, including the utilization of pivot tables.
# • Project: Breast-Cancer Prediction on Wisconsin Diagnostic Dataset 2023
# o Tools/ Tech: Python, Jupyter NB, ML, Data Preprocessing and Visualizations.
# o Overview: The goal is to predict whether a breast mass is malignant or benign based on features extracted from digitized images
# of a fine needle aspirate (FNA) of a breast mass. Models used are ANN, and KNN.
# CERTIFICATIONS
# • Completion of, Data Analytics Cohort Training from Metvy. 2023
# • Competed, and qualified in a National Level Hackathon, Data Tales ’23, conducted by GLIM, Chennai, via Unstop. 2023
# • Completion of Microsoft Excel – Data Analytics, Power Query, from Udemy.com. 2023
# • Certificate of completion of Project – Analyzing Website Visitors using Google Analytics Segments, via Coursera 2023
# • Semi-Finalists, Level 2 in Flipkart Grid 4.0 SDE Challenge, via Unstop. 2022
# • Completion of Problem Solving and Training, using Python, by Dept. of Training and Placement, KIIT CAAS. 2022
# SEMINARS / WORKSHOPS
# • Attended a technical webinar on, Generative AI – Midjourney, via Analytics Vidhya.
# • Attended and participated in 2 – Days Live Hands-on Data Analytics Workshop, conducted by Jobaaj Learnings.
# • Attended A Live Talk by Prof. Sanjay Madria on– Machine Learning for Emotion Prediction, Ideology Detection, using COVID-
# 19 Tweets.
# RECOGNITIONS
# • Received Letter of Recommendation, for Data Analytics Cohort Training, from Metvy.
# • Member of Amazon Emerging Talent Community, via AWS.
# SKILLS
# • Programming Languages: Python, SQL, C Programming.
# • Platforms/ Environments: MS Excel, MS Power BI, SQL Workbench, Jupyter NB, GitHub, RDBMS, AWS.
# • Soft Skills: Critical Thinking, Team Collaboration, Upskilling Fundamentals, Leadership, Problem Solving.

# %%
# Regular expression patterns for extracting different sections
name_pattern = r"^([A-Za-z\s]+)\s*$"
email_pattern = r"Email:\s*(\S+)\s*"
phone_pattern = r"Ph.\s*([\d\s]+)"
address_pattern = r"([^⋄]+),"
profile_pattern = r"PROFILE\s*([\s\S]+?)\s*EDUCATION"
education_pattern = r"•\s*(.*?)\s*–\s*(.*?)\s*–\s*(.*?)\n"
experience_pattern = r"•\s*(.*?)\s*(\d{4}\s*–\s*.*?)\n"
skills_set_pattern = r"SKILLS\s+•\s*(.*?)\s+"

# %%
parsed_resume = {
    "NAME": None,
    "EMAIL-ID": None,
    "PHONE": None,
    "ADDRESS": None,
    "EDUCATION": [],
    "EXPERIENCE": [],
    "PROJECTS": None,
    "CERTIFICATIONS": None,
    "TECHNICAL SKILLS": None,
    "SKILLS SET": None,
}

# %%
# Extract information using NER
for ent in resume_gen.ents:
    if ent.label_ == "PERSON":
        parsed_resume["NAME"] = ent.text
    elif ent.label_ == "EMAIL":
        parsed_resume["EMAIL-ID"] = ent.text
    elif ent.label_ == "PHONE":
        parsed_resume["PHONE"] = ent.text
    elif ent.label_ == "GPE":
        parsed_resume["ADDRESS"] = ent.text

# %%
# Define training data for section classification
section_text = [
    "EDUCATION", "EXPERIENCE", "PROJECTS", "CERTIFICATIONS",
    "TECHNICAL SKILLS", "SKILLS SET"
]
section_labels = ["EDUCATION"] * len(parsed_resume["EDUCATION"]) + \
                 ["EXPERIENCE"] * len(parsed_resume["EXPERIENCE"]) + \
                 ["PROJECTS"] * len(parsed_resume["PROJECTS"]) + \
                 ["CERTIFICATIONS"] * len(parsed_resume["CERTIFICATIONS"]) + \
                 ["TECHNICAL SKILLS"] * len(parsed_resume["TECHNICAL SKILLS"]) + \
                 ["SKILLS SET"] * len(parsed_resume["SKILLS SET"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 6>()
#       1 # Define training data for section classification
#       2 section_text = [
#       3     "EDUCATION", "EXPERIENCE", "PROJECTS", "CERTIFICATIONS",
#       4     "TECHNICAL SKILLS", "SKILLS SET"
#       5 ]
#       6 section_labels = ["EDUCATION"] * len(parsed_resume["EDUCATION"]) + \
#       7                  ["EXPERIENCE"] * len(parsed_resume["EXPERIENCE"]) + \
# ----> 8                  ["PROJECTS"] * len(parsed_resume["PROJECTS"]) + \
#       9                  ["CERTIFICATIONS"] * len(parsed_resume["CERTIFICATIONS"]) + \
#      10                  ["TECHNICAL SKILLS"] * len(parsed_resume["TECHNICAL SKILLS"]) + \
#      11                  ["SKILLS SET"] * len(parsed_resume["SKILLS SET"])
#
# TypeError: object of type 'NoneType' has no len()

# %%
parsed_resume
# Out:
# {'NAME': 'Jupyter NB',
#  'EMAIL-ID': None,
#  'PHONE': None,
#  'ADDRESS': 'Metvy',
#  'PROFILE': None,
#  'EDUCATION': [],
#  'EXPERIENCE': [],
#  'PROJECTS': None,
#  'CERTIFICATIONS': None,
#  'TECHNICAL SKILLS': None,
#  'SKILLS SET': None}

# %%
# Build a machine learning pipeline for section classification
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LinearSVC())
])

# %%
# Fit the pipeline on the training data
pipeline.fit(section_text, section_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 2>()
#       1 # Fit the pipeline on the training data
# ----> 2 pipeline.fit(section_text, section_labels)
#
# NameError: name 'section_labels' is not defined

# %%
# ... (Rest of the section_labels creation)


# Predict sections for each piece of text
predicted_sections = pipeline.predict(section_text)

# Assign predicted sections to the parsed_resume dictionary
for section, predicted_section in zip(section_text, predicted_sections):
    parsed_resume[section] = predicted_section

# Print the parsed resume data
print(json.dumps(parsed_resume, indent=4))
