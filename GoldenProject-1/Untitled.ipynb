# %%
# !pip install -U spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install spacy_transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for spacy_transformers from https://files.pythonhosted.org/packages/ec/16/0afe6df4d4a3e336f4363fa8dc0582d00d735fde2eb88a211995b19579bd/spacy_transformers-1.2.5-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for transformers<4.31.0,>=3.4.0 from https://files.pythonhosted.org/packages/5b/0b/e45d26ccd28568013523e04f325432ea88a442b4e3020b757cf4361f0120/transformers-4.30.2-py3-none-any.whl.metadata
# ...
#      -------------------------------------- 113.6/113.6 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 172.4/172.4 MB 3.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 186.7/186.7 kB 3.8 MB/s eta 0:00:00
# ...
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\KIIT\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
# ...

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 import spacy
#
# File ~\AppData\Roaming\Python\Python39\site-packages\spacy\__init__.py:6, in <module>
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Roaming\Python\Python39\site-packages\spacy\errors.py:3, in <module>
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\spacy\compat.py:4, in <module>
#       1 """Helpers for Python and platform compatibility."""
# ...
